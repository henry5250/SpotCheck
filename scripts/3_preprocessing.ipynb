# %% [markdown]
# <a href="https://colab.research.google.com/github/henry5250/SpotCheck/blob/main/scripts/3_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read in the zip files and load images

# %%
# import the modules needed
import zipfile
import os

# zip file paths and directory where images are stored
zip_files = ['/content/Harmonia_axyridis.zip', '/content/Coccinella_novemnotata.zip']
extract_dir = '/content/extracted_images'

os.makedirs(extract_dir, exist_ok=True)

# extract all the images from the zip file into the directory
for zip_file in zip_files:
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)

print(f"All files extracted to {extract_dir}")
# Out:
# All files extracted to /content/extracted_images

# %%
# import modules
import os
import random
from IPython.display import display, Image

# list of paths to the specific directories for each species
extracted_dirs = [os.path.join(extract_dir, os.path.splitext(os.path.basename(zip_file))[0]) for zip_file in zip_files]

for directory in extracted_dirs:
    print(f"Listing images from: {directory}")
    image_files = [f for f in os.listdir(directory) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    if not image_files:
        print("No image files found.")
        continue

    # show a few random images
    sample_images = random.sample(image_files, min(5, len(image_files)))
    for image_name in sample_images:
        image_path = os.path.join(directory, image_name)
        print(f"Displaying: {image_name}")
        display(Image(filename=image_path))
    print("-" * 30)
# Out:
# Listing images from: /content/extracted_images/Harmonia_axyridis
# Displaying: 0089.jpg
# Displaying: 0019.jpg
# Displaying: 0117.jpg
# Displaying: 0079.jpg
# Displaying: 0094.jpg
# ------------------------------
# Listing images from: /content/extracted_images/Coccinella_novemnotata
# Displaying: 0118.jpg
# Displaying: 0056.jpg
# Displaying: 0066.jpg
# Displaying: 0037.jpg
# Displaying: 0106.jpg
# ------------------------------

# %% [markdown]
# # Preprocessing Steps:
# - resize all the images in the files to 224x224 pixels
# - normalize all the resized images by scaling the pixel values from [0,1]

# %% [markdown]
# # Resize all the images to 224x224 pixels

# %%
# install Pillow library
# %pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)

# %%
# import modules
from PIL import Image
import os

# function that takes image path and tuple target size
def resize_and_save_image(image_path, target_size):
    """
    Resizes an image and saves it, overwriting the original file. # Docstring: Explains what the function does.

    Args:
        image_path (str): The path to the image file. # Docstring: Describes the 'image_path' argument.
        target_size (tuple): The target size as (width, height). # Docstring: Describes the 'target_size' argument.
    """
    try:
        img = Image.open(image_path)
        img_resized = img.resize(target_size)
        img_resized.save(image_path)
        print(f"Resized and saved: {image_path}")
    except FileNotFoundError:
        print(f"Error: File not found at {image_path}")
    except Exception as e:
        print(f"An error occurred while processing {image_path}: {e}")

# %%
# make the target size for the images as a tuple
# our target dimensions for image resizing is 224x224 pixels
target_size = (224, 224)

# iterate through the directories
for directory in extracted_dirs:
    print(f"Processing images in: {directory}")
    # list all files in each directory
    all_files = os.listdir(directory)

    # include only image files
    image_files = [f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    if not image_files:
        print("No image files found in this directory.")
        continue

    # create the full image path for the image files
    for image_name in image_files:
        image_path = os.path.join(directory, image_name)
        # save the images
        resize_and_save_image(image_path, target_size)
# Out:
# Processing images in: /content/extracted_images/Harmonia_axyridis
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0052.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0002.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0093.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0069.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0072.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0081.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0051.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0005.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0043.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0114.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0013.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0100.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0102.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0021.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0063.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0118.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0092.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0120.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0032.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0104.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0077.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0116.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0047.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0012.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0009.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0106.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0091.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0079.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0110.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0037.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0059.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0023.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0075.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0001.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0060.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0119.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0026.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0014.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0029.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0010.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0058.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0103.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0008.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0088.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0041.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0084.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0057.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0038.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0066.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0112.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0046.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0042.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0096.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0117.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0055.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0061.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0045.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0111.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0053.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0018.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0004.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0044.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0083.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0085.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0003.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0095.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0024.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0109.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0105.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0068.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0097.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0071.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0040.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0107.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0006.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0050.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0086.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0031.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0056.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0064.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0007.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0027.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0090.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0082.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0036.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0065.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0049.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0099.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0030.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0074.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0070.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0033.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0011.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0016.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0039.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0087.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0022.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0078.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0034.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0080.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0015.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0076.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0062.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0098.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0019.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0089.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0094.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0073.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0028.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0067.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0101.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0020.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0054.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0048.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0113.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0115.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0017.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0108.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0035.jpg
# Resized and saved: /content/extracted_images/Harmonia_axyridis/0025.jpg
# Processing images in: /content/extracted_images/Coccinella_novemnotata
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0052.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0002.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0093.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0069.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0072.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0081.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0051.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0005.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0043.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0114.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0013.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0100.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0102.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0021.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0063.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0118.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0092.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0120.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0032.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0104.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0077.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0116.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0047.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0012.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0009.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0106.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0091.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0079.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0110.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0037.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0059.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0023.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0075.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0001.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0060.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0119.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0026.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0014.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0029.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0010.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0058.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0103.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0008.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0088.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0041.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0084.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0057.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0038.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0066.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0112.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0046.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0042.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0096.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0117.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0055.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0061.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0045.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0111.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0053.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0018.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0004.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0044.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0083.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0085.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0003.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0095.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0024.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0109.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0105.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0068.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0097.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0071.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0040.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0107.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0006.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0050.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0086.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0031.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0056.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0064.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0007.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0027.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0090.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0082.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0036.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0065.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0049.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0099.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0030.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0074.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0070.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0033.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0011.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0016.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0039.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0087.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0022.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0078.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0034.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0080.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0015.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0076.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0062.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0098.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0019.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0089.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0094.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0073.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0028.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0067.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0101.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0020.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0054.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0048.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0113.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0115.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0017.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0108.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0035.jpg
# Resized and saved: /content/extracted_images/Coccinella_novemnotata/0025.jpg

# %%
# import modules
import os
from PIL import Image

# look at some images that are already resized
verification_images = []
for directory in extracted_dirs:
    all_files = os.listdir(directory)
    image_files = [f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    if image_files:
        # look at 3 random images
        verification_images.extend([os.path.join(directory, img) for img in random.sample(image_files, min(3, len(image_files)))])

# verify the dimensions
print("\nVerifying dimensions of a few resized images:")
for image_path in verification_images:
    try:
        img = Image.open(image_path)
        print(f"Image: {os.path.basename(image_path)}, Dimensions: {img.size}")
        img.close()
    except FileNotFoundError:
        print(f"Error: File not found at {image_path}")
    except Exception as e:
        print(f"An error occurred while verifying {image_path}: {e}")
# Out:
# Verifying dimensions of a few resized images:
# Image: 0046.jpg, Dimensions: (224, 224)
# Image: 0004.jpg, Dimensions: (224, 224)
# Image: 0057.jpg, Dimensions: (224, 224)
# Image: 0057.jpg, Dimensions: (224, 224)
# Image: 0083.jpg, Dimensions: (224, 224)
# Image: 0032.jpg, Dimensions: (224, 224)

# %% [markdown]
# # Normalize the images

# %%
# import modules
import numpy as np
from PIL import Image

# function that resizes, normalizes, and saves the images
def resize_normalize_and_save_image(image_path, target_size):
    """
    Resizes and normalizes an image, then saves it, overwriting the original file. # Docstring: Describes the function's overall purpose.

    Args:
        image_path (str): The path to the image file. # Docstring: Describes the 'image_path' argument.
        target_size (tuple): The target size as (width, height). # Docstring: Describes the 'target_size' argument.
    """
    try:
        img = Image.open(image_path)
        img_resized = img.resize(target_size)


        img_array = np.array(img_resized)
        img_normalized = img_array / 255.0


        if img_resized.mode == 'RGB':
            img_processed = Image.fromarray((img_normalized * 255).astype(np.uint8), 'RGB')
        elif img_resized.mode == 'L':
             img_processed = Image.fromarray((img_normalized * 255).astype(np.uint8), 'L')
        else:

             img_processed = Image.fromarray((img_normalized * 255).astype(np.uint8))

        img_processed.save(image_path)
        print(f"Resized, normalized, and saved: {image_path}")
    except FileNotFoundError:
        print(f"Error: File not found at {image_path}")
    except Exception as e:
        print(f"An error occurred while processing {image_path}: {e}")

# %%
# go through the list of directories
for directory in extracted_dirs:
    print(f"Processing images in: {directory}")

    all_files = os.listdir(directory)

    # filter to only include images
    image_files = [f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    if not image_files:
        print("No image files found in this directory.")
        continue

    # get the full image path for each
    for image_name in image_files:
        image_path = os.path.join(directory, image_name)
        # call the function created earlier
        resize_normalize_and_save_image(image_path, target_size)
# Out:
# Processing images in: /content/extracted_images/Harmonia_axyridis
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0052.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0002.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0093.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0069.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0072.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0081.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0051.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0005.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0043.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0114.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0013.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0100.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0102.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0021.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0063.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0118.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0092.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0120.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0032.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0104.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0077.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0116.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0047.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0012.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0009.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0106.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0091.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0079.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0110.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0037.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0059.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0023.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0075.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0001.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0060.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0119.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0026.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0014.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0029.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0010.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0058.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0103.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0008.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0088.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0041.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0084.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0057.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0038.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0066.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0112.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0046.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0042.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0096.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0117.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0055.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0061.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0045.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0111.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0053.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0018.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0004.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0044.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0083.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0085.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0003.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0095.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0024.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0109.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0105.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0068.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0097.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0071.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0040.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0107.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0006.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0050.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0086.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0031.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0056.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0064.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0007.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0027.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0090.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0082.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0036.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0065.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0049.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0099.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0030.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0074.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0070.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0033.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0011.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0016.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0039.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0087.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0022.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0078.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0034.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0080.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0015.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0076.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0062.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0098.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0019.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0089.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0094.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0073.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0028.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0067.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0101.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0020.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0054.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0048.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0113.jpg
# /tmp/ipython-input-2563738584.py:24: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   img_processed = Image.fromarray((img_normalized * 255).astype(np.uint8), 'RGB')
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0115.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0017.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0108.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0035.jpg
# Resized, normalized, and saved: /content/extracted_images/Harmonia_axyridis/0025.jpg
# Processing images in: /content/extracted_images/Coccinella_novemnotata
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0052.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0002.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0093.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0069.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0072.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0081.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0051.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0005.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0043.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0114.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0013.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0100.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0102.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0021.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0063.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0118.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0092.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0120.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0032.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0104.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0077.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0116.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0047.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0012.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0009.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0106.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0091.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0079.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0110.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0037.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0059.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0023.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0075.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0001.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0060.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0119.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0026.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0014.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0029.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0010.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0058.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0103.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0008.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0088.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0041.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0084.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0057.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0038.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0066.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0112.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0046.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0042.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0096.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0117.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0055.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0061.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0045.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0111.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0053.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0018.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0004.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0044.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0083.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0085.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0003.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0095.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0024.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0109.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0105.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0068.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0097.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0071.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0040.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0107.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0006.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0050.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0086.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0031.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0056.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0064.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0007.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0027.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0090.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0082.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0036.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0065.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0049.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0099.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0030.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0074.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0070.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0033.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0011.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0016.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0039.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0087.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0022.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0078.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0034.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0080.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0015.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0076.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0062.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0098.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0019.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0089.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0094.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0073.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0028.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0067.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0101.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0020.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0054.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0048.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0113.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0115.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0017.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0108.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0035.jpg
# Resized, normalized, and saved: /content/extracted_images/Coccinella_novemnotata/0025.jpg

# %%
# import modules
import numpy as np
from PIL import Image
import os
import random

# verify the resizing and normalization occurred in images
verification_images = []
for directory in extracted_dirs:
    all_files = os.listdir(directory)
    image_files = [f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    if image_files:
        # choose 3 random images
        verification_images.extend([os.path.join(directory, img) for img in random.sample(image_files, min(3, len(image_files)))])

# verify the dimensions and pixel value ranges
print("\nVerifying dimensions and pixel values of a few processed images:")
for image_path in verification_images:
    try:
        img = Image.open(image_path)
        print(f"Image: {os.path.basename(image_path)}")

        # check dimensions
        print(f"  Dimensions: {img.size}")
        if img.size != target_size:
            print(f"  Warning: Dimensions mismatch. Expected {target_size}, got {img.size}")

        # check pixel values
        img_array = np.array(img)
        min_pixel_value = np.min(img_array)
        max_pixel_value = np.max(img_array)

        print(f"  Min pixel value: {min_pixel_value}")
        print(f"  Max pixel value: {max_pixel_value}")

        # check if values are in range and proper normalization
        if min_pixel_value < 0 or max_pixel_value > 255:
             print(f"  Warning: Pixel values outside the expected range [0, 255].")


        img.close()
    except FileNotFoundError:
        print(f"Error: File not found at {image_path}")
    except Exception as e:
        print(f"An error occurred while verifying {image_path}: {e}")
# Out:
# Verifying dimensions and pixel values of a few processed images:
# Image: 0023.jpg
#   Dimensions: (224, 224)
#   Min pixel value: 0
#   Max pixel value: 255
# Image: 0006.jpg
#   Dimensions: (224, 224)
#   Min pixel value: 0
#   Max pixel value: 255
# Image: 0001.jpg
#   Dimensions: (224, 224)
#   Min pixel value: 0
#   Max pixel value: 255
# Image: 0104.jpg
#   Dimensions: (224, 224)
#   Min pixel value: 0
#   Max pixel value: 255
# Image: 0102.jpg
#   Dimensions: (224, 224)
#   Min pixel value: 0
#   Max pixel value: 255
# Image: 0106.jpg
#   Dimensions: (224, 224)
#   Min pixel value: 0
#   Max pixel value: 255

# %% [markdown]
# ## Rename the image files to be identified by species rather than folder
# - _c for coccinella_novemtata
# - _h for harmonia_axyridis

# %%
# import modules
import os

# define the species identifiers
species_identifiers_for_rename = {
    'Harmonia_axyridis': '_h',
    'Coccinella_novemnotata': '_c'
}

print("Renaming image files in place...")

for directory in extracted_dirs:
    species_name = os.path.basename(directory)
    species_id = species_identifiers_for_rename.get(species_name)

    if species_id is None:
        print(f"Warning: No specific identifier for species: {species_name}. Skipping renaming for this directory.")
        continue

    print(f"Processing directory: {directory} with identifier {species_id}")

    all_files = os.listdir(directory)
    image_files = [f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    if not image_files:
        print(f"No image files found in {directory} to rename.")
        continue

    for image_name in image_files:
        original_path = os.path.join(directory, image_name)
        base_name, ext = os.path.splitext(image_name)

       # make the new file name based on the identifier
        new_image_name = f"{base_name}{species_id}{ext}"
        new_path = os.path.join(directory, new_image_name)

        # rename the file
        try:
            os.rename(original_path, new_path)
            print(f"  Renamed: {image_name} to {new_image_name}")
        except Exception as e:
            print(f"  Error renaming {image_name}: {e}")

print("Finished renaming all applicable image files.")
# Out:
# Renaming image files in place...
# Processing directory: /content/extracted_images/Harmonia_axyridis with identifier _h
#   Renamed: 0052.jpg to 0052_h.jpg
#   Renamed: 0002.jpg to 0002_h.jpg
#   Renamed: 0093.jpg to 0093_h.jpg
#   Renamed: 0069.jpg to 0069_h.jpg
#   Renamed: 0072.jpg to 0072_h.jpg
#   Renamed: 0081.jpg to 0081_h.jpg
#   Renamed: 0051.jpg to 0051_h.jpg
#   Renamed: 0005.jpg to 0005_h.jpg
#   Renamed: 0043.jpg to 0043_h.jpg
#   Renamed: 0114.jpg to 0114_h.jpg
#   Renamed: 0013.jpg to 0013_h.jpg
#   Renamed: 0100.jpg to 0100_h.jpg
#   Renamed: 0102.jpg to 0102_h.jpg
#   Renamed: 0021.jpg to 0021_h.jpg
#   Renamed: 0063.jpg to 0063_h.jpg
#   Renamed: 0118.jpg to 0118_h.jpg
#   Renamed: 0092.jpg to 0092_h.jpg
#   Renamed: 0120.jpg to 0120_h.jpg
#   Renamed: 0032.jpg to 0032_h.jpg
#   Renamed: 0104.jpg to 0104_h.jpg
#   Renamed: 0077.jpg to 0077_h.jpg
#   Renamed: 0116.jpg to 0116_h.jpg
#   Renamed: 0047.jpg to 0047_h.jpg
#   Renamed: 0012.jpg to 0012_h.jpg
#   Renamed: 0009.jpg to 0009_h.jpg
#   Renamed: 0106.jpg to 0106_h.jpg
#   Renamed: 0091.jpg to 0091_h.jpg
#   Renamed: 0079.jpg to 0079_h.jpg
#   Renamed: 0110.jpg to 0110_h.jpg
#   Renamed: 0037.jpg to 0037_h.jpg
#   Renamed: 0059.jpg to 0059_h.jpg
#   Renamed: 0023.jpg to 0023_h.jpg
#   Renamed: 0075.jpg to 0075_h.jpg
#   Renamed: 0001.jpg to 0001_h.jpg
#   Renamed: 0060.jpg to 0060_h.jpg
#   Renamed: 0119.jpg to 0119_h.jpg
#   Renamed: 0026.jpg to 0026_h.jpg
#   Renamed: 0014.jpg to 0014_h.jpg
#   Renamed: 0029.jpg to 0029_h.jpg
#   Renamed: 0010.jpg to 0010_h.jpg
#   Renamed: 0058.jpg to 0058_h.jpg
#   Renamed: 0103.jpg to 0103_h.jpg
#   Renamed: 0008.jpg to 0008_h.jpg
#   Renamed: 0088.jpg to 0088_h.jpg
#   Renamed: 0041.jpg to 0041_h.jpg
#   Renamed: 0084.jpg to 0084_h.jpg
#   Renamed: 0057.jpg to 0057_h.jpg
#   Renamed: 0038.jpg to 0038_h.jpg
#   Renamed: 0066.jpg to 0066_h.jpg
#   Renamed: 0112.jpg to 0112_h.jpg
#   Renamed: 0046.jpg to 0046_h.jpg
#   Renamed: 0042.jpg to 0042_h.jpg
#   Renamed: 0096.jpg to 0096_h.jpg
#   Renamed: 0117.jpg to 0117_h.jpg
#   Renamed: 0055.jpg to 0055_h.jpg
#   Renamed: 0108.jpg to 0108_c.jpg
#   Renamed: 0035.jpg to 0035_c.jpg
#   Renamed: 0025.jpg to 0025_c.jpg
# Finished renaming all applicable image files.

# %% [markdown]
# # Verify the file names

# %%
import os
import random

print("Verifying renamed image files:")
for directory in extracted_dirs:
    species_name = os.path.basename(directory)
    expected_id = species_identifiers_for_rename.get(species_name)

    print(f"Checking directory: {directory}")
    all_files = os.listdir(directory)
    renamed_image_files = [f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    if not renamed_image_files:
        print(f"  No image files found in {directory} (after renaming).")
        continue

    sample_files = random.sample(renamed_image_files, min(5, len(renamed_image_files)))
    for filename in sample_files:
        if expected_id and expected_id in filename:
            print(f"  Sample file: {filename} (contains expected '{expected_id}')")
        else:
            print(f"  Sample file: {filename} (WARNING: Does not contain expected '{expected_id}' or ID is missing)")

print("Verification complete.")
# Out:
# Verifying renamed image files:
# Checking directory: /content/extracted_images/Harmonia_axyridis
#   Sample file: 0078_h.jpg (contains expected '_h')
#   Sample file: 0037_h.jpg (contains expected '_h')
#   Sample file: 0117_h.jpg (contains expected '_h')
#   Sample file: 0030_h.jpg (contains expected '_h')
#   Sample file: 0027_h.jpg (contains expected '_h')
# Checking directory: /content/extracted_images/Coccinella_novemnotata
#   Sample file: 0003_c.jpg (contains expected '_c')
#   Sample file: 0018_c.jpg (contains expected '_c')
#   Sample file: 0082_c.jpg (contains expected '_c')
#   Sample file: 0006_c.jpg (contains expected '_c')
#   Sample file: 0097_c.jpg (contains expected '_c')
# Verification complete.

# %% [markdown]
# # Download finalized images into final zip files

# %%
import os
import zipfile

species_identifiers = {
    'Harmonia_axyridis': '_h',
    'Coccinella_novemnotata': '_c'
}

# define directory where the final zip files will be saved
output_zip_dir = '/content/final_species_zips'
os.makedirs(output_zip_dir, exist_ok=True)

print("Creating new final species zip files...")

for directory in extracted_dirs:
    species_name = os.path.basename(directory)

    species_id = species_identifiers.get(species_name)

    if species_id is None:
        print(f"Warning: No identifier found for species: {species_name}. Skipping zip creation.")
        continue

    # new zip file name 'final_SpeciesName.zip'
    new_zip_filename = os.path.join(output_zip_dir, f"final_{species_name}.zip")

    print(f"\nCreating zip file for {species_name}: {new_zip_filename}")
    with zipfile.ZipFile(new_zip_filename, 'w', zipfile.ZIP_DEFLATED) as new_zip_file:
        all_files_in_dir = os.listdir(directory)

        image_files_in_dir = [f for f in all_files_in_dir if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

        if not image_files_in_dir:
            print(f"No image files found in {directory}. New zip file will be empty.")

        for image_name in image_files_in_dir:
            original_image_path = os.path.join(directory, image_name)

            new_zip_file.write(original_image_path, arcname=image_name)
            print(f"  Added: {image_name}")

    print(f"Finished creating {new_zip_filename}")

print("\nAll final species zip files created.")
# Out:
# Creating new final species zip files...
#
# Creating zip file for Harmonia_axyridis: /content/final_species_zips/final_Harmonia_axyridis.zip
#   Added: 0031_h.jpg
#   Added: 0032_h.jpg
#   Added: 0057_h.jpg
#   Added: 0013_h.jpg
#   Added: 0036_h.jpg
#   Added: 0087_h.jpg
#   Added: 0012_h.jpg
#   Added: 0053_h.jpg
#   Added: 0083_h.jpg
#   Added: 0022_h.jpg
#   Added: 0065_h.jpg
#   Added: 0044_h.jpg
#   Added: 0086_h.jpg
#   Added: 0045_h.jpg
#   Added: 0047_h.jpg
#   Added: 0116_h.jpg
#   Added: 0085_h.jpg
#   Added: 0111_h.jpg
#   Added: 0033_h.jpg
#   Added: 0060_h.jpg
#   Added: 0076_h.jpg
#   Added: 0007_h.jpg
#   Added: 0061_h.jpg
#   Added: 0105_h.jpg
#   Added: 0095_h.jpg
#   Added: 0014_h.jpg
#   Added: 0041_h.jpg
#   Added: 0112_h.jpg
#   Added: 0003_h.jpg
#   Added: 0072_h.jpg
#   Added: 0088_h.jpg
#   Added: 0025_h.jpg
#   Added: 0023_h.jpg
#   Added: 0089_h.jpg
#   Added: 0079_h.jpg
#   Added: 0055_h.jpg
#   Added: 0082_h.jpg
#   Added: 0009_h.jpg
#   Added: 0078_h.jpg
#   Added: 0015_h.jpg
#   Added: 0091_h.jpg
#   Added: 0064_h.jpg
#   Added: 0039_h.jpg
#   Added: 0006_h.jpg
#   Added: 0081_h.jpg
#   Added: 0102_h.jpg
#   Added: 0040_h.jpg
#   Added: 0010_h.jpg
#   Added: 0090_h.jpg
#   Added: 0028_h.jpg
#   Added: 0035_h.jpg
#   Added: 0115_h.jpg
#   Added: 0067_h.jpg
#   Added: 0075_h.jpg
#   Added: 0052_h.jpg
#   Added: 0071_h.jpg
#   Added: 0117_h.jpg
#   Added: 0092_h.jpg
#   Added: 0118_h.jpg
#   Added: 0021_h.jpg
#   Added: 0119_h.jpg
#   Added: 0069_h.jpg
#   Added: 0050_h.jpg
#   Added: 0020_h.jpg
#   Added: 0062_h.jpg
#   Added: 0068_h.jpg
#   Added: 0016_h.jpg
#   Added: 0114_h.jpg
#   Added: 0011_h.jpg
#   Added: 0109_h.jpg
#   Added: 0113_h.jpg
#   Added: 0005_h.jpg
#   Added: 0042_h.jpg
#   Added: 0110_h.jpg
#   Added: 0058_h.jpg
#   Added: 0094_h.jpg
#   Added: 0024_h.jpg
#   Added: 0077_h.jpg
#   Added: 0100_h.jpg
#   Added: 0043_h.jpg
#   Added: 0017_h.jpg
#   Added: 0098_h.jpg
#   Added: 0096_h.jpg
#   Added: 0027_h.jpg
#   Added: 0073_h.jpg
#   Added: 0037_h.jpg
#   Added: 0008_h.jpg
#   Added: 0099_h.jpg
#   Added: 0080_h.jpg
#   Added: 0084_h.jpg
#   Added: 0103_h.jpg
#   Added: 0108_h.jpg
#   Added: 0097_h.jpg
#   Added: 0056_h.jpg
#   Added: 0030_h.jpg
#   Added: 0001_h.jpg
#   Added: 0018_h.jpg
#   Added: 0101_h.jpg
#   Added: 0074_h.jpg
#   Added: 0049_h.jpg
#   Added: 0046_h.jpg
#   Added: 0038_h.jpg
#   Added: 0048_h.jpg
#   Added: 0106_h.jpg
#   Added: 0019_h.jpg
#   Added: 0104_h.jpg
#   Added: 0004_h.jpg
#   Added: 0026_h.jpg
#   Added: 0066_h.jpg
#   Added: 0059_h.jpg
#   Added: 0093_h.jpg
#   Added: 0054_h.jpg
#   Added: 0002_h.jpg
#   Added: 0051_h.jpg
#   Added: 0107_h.jpg
#   Added: 0120_h.jpg
#   Added: 0029_h.jpg
#   Added: 0070_h.jpg
#   Added: 0063_h.jpg
#   Added: 0034_h.jpg
# Finished creating /content/final_species_zips/final_Harmonia_axyridis.zip
#
# Creating zip file for Coccinella_novemnotata: /content/final_species_zips/final_Coccinella_novemnotata.zip
#   Added: 0095_c.jpg
#   Added: 0069_c.jpg
#   Added: 0021_c.jpg
#   Added: 0038_c.jpg
#   Added: 0108_c.jpg
#   Added: 0005_c.jpg
#   Added: 0007_c.jpg
#   Added: 0044_c.jpg
#   Added: 0041_c.jpg
#   Added: 0080_c.jpg
#   Added: 0048_c.jpg
#   Added: 0068_c.jpg
#   Added: 0032_c.jpg
#   Added: 0065_c.jpg
#   Added: 0059_c.jpg
#   Added: 0104_c.jpg
#   Added: 0088_c.jpg
#   Added: 0118_c.jpg
#   Added: 0076_c.jpg
#   Added: 0070_c.jpg
#   Added: 0002_c.jpg
#   Added: 0028_c.jpg
#   Added: 0087_c.jpg
#   Added: 0018_c.jpg
#   Added: 0081_c.jpg
#   Added: 0105_c.jpg
#   Added: 0086_c.jpg
#   Added: 0100_c.jpg
#   Added: 0114_c.jpg
#   Added: 0056_c.jpg
#   Added: 0029_c.jpg
#   Added: 0051_c.jpg
#   Added: 0084_c.jpg
#   Added: 0072_c.jpg
#   Added: 0046_c.jpg
#   Added: 0111_c.jpg
#   Added: 0049_c.jpg
#   Added: 0071_c.jpg
#   Added: 0058_c.jpg
#   Added: 0066_c.jpg
#   Added: 0023_c.jpg
#   Added: 0039_c.jpg
#   Added: 0073_c.jpg
#   Added: 0115_c.jpg
#   Added: 0009_c.jpg
#   Added: 0074_c.jpg
#   Added: 0090_c.jpg
#   Added: 0042_c.jpg
#   Added: 0013_c.jpg
#   Added: 0015_c.jpg
#   Added: 0093_c.jpg
#   Added: 0003_c.jpg
#   Added: 0083_c.jpg
#   Added: 0077_c.jpg
#   Added: 0014_c.jpg
#   Added: 0099_c.jpg
#   Added: 0017_c.jpg
#   Added: 0008_c.jpg
#   Added: 0033_c.jpg
#   Added: 0025_c.jpg
#   Added: 0060_c.jpg
#   Added: 0024_c.jpg
#   Added: 0106_c.jpg
#   Added: 0050_c.jpg
#   Added: 0043_c.jpg
#   Added: 0057_c.jpg
#   Added: 0094_c.jpg
#   Added: 0016_c.jpg
#   Added: 0010_c.jpg
#   Added: 0045_c.jpg
#   Added: 0116_c.jpg
#   Added: 0075_c.jpg
#   Added: 0067_c.jpg
#   Added: 0055_c.jpg
#   Added: 0096_c.jpg
#   Added: 0054_c.jpg
#   Added: 0101_c.jpg
#   Added: 0120_c.jpg
#   Added: 0117_c.jpg
#   Added: 0019_c.jpg
#   Added: 0052_c.jpg
#   Added: 0110_c.jpg
#   Added: 0006_c.jpg
#   Added: 0091_c.jpg
#   Added: 0064_c.jpg
#   Added: 0109_c.jpg
#   Added: 0085_c.jpg
#   Added: 0103_c.jpg
#   Added: 0012_c.jpg
#   Added: 0053_c.jpg
#   Added: 0031_c.jpg
#   Added: 0035_c.jpg
#   Added: 0047_c.jpg
#   Added: 0036_c.jpg
#   Added: 0034_c.jpg
#   Added: 0030_c.jpg
#   Added: 0097_c.jpg
#   Added: 0063_c.jpg
#   Added: 0089_c.jpg
#   Added: 0011_c.jpg
#   Added: 0107_c.jpg
#   Added: 0026_c.jpg
#   Added: 0020_c.jpg
#   Added: 0078_c.jpg
#   Added: 0027_c.jpg
#   Added: 0082_c.jpg
#   Added: 0079_c.jpg
#   Added: 0102_c.jpg
#   Added: 0001_c.jpg
#   Added: 0062_c.jpg
#   Added: 0061_c.jpg
#   Added: 0022_c.jpg
#   Added: 0004_c.jpg
#   Added: 0113_c.jpg
#   Added: 0119_c.jpg
#   Added: 0040_c.jpg
#   Added: 0098_c.jpg
#   Added: 0037_c.jpg
#   Added: 0112_c.jpg
#   Added: 0092_c.jpg
# Finished creating /content/final_species_zips/final_Coccinella_novemnotata.zip
#
# All final species zip files created.

# %%
import zipfile
import os
import random

# list all zip files in new diretory
processed_zip_files = [os.path.join(output_zip_dir, f) for f in os.listdir(output_zip_dir) if f.startswith('final_') and f.endswith('.zip')]

print("Verifying contents of newly created final species zip files:")
for zip_path in processed_zip_files:
    print(f"\nChecking zip file: {zip_path}")
    try:
        with zipfile.ZipFile(zip_path, 'r') as zf:
            file_list = zf.namelist()

            if not file_list:
                print(f"  Warning: Zip file {zip_path} is empty.")
                continue

            species_name_from_zip = os.path.basename(zip_path).replace('final_', '').replace('.zip', '')
            expected_species_id = species_identifiers.get(species_name_from_zip)

            if expected_species_id is None:
                print(f"  Warning: Could not determine expected species ID for {species_name_from_zip}. \
Ignoring filename verification for this zip.")
                continue

            # check file names inside zip
            sample_files_to_check = random.sample(file_list, min(5, len(file_list)))
            for filename_in_zip in sample_files_to_check:
                if expected_species_id in filename_in_zip:
                    print(f"  Verified: '{filename_in_zip}' contains '{expected_species_id}'.")
                else:
                    print(f"  Error: '{filename_in_zip}' in {zip_path} does NOT contain expected identifier '{expected_species_id}'.")

    except zipfile.BadZipFile:
        print(f"  Error: {zip_path} is not a valid zip file.")
    except Exception as e:
        print(f"  An unexpected error occurred while checking {zip_path}: {e}")

print("\nFinal zip file verification complete.")
# Out:
# Verifying contents of newly created final species zip files:
#
# Checking zip file: /content/final_species_zips/final_Coccinella_novemnotata.zip
#   Verified: '0044_c.jpg' contains '_c'.
#   Verified: '0067_c.jpg' contains '_c'.
#   Verified: '0093_c.jpg' contains '_c'.
#   Verified: '0031_c.jpg' contains '_c'.
#   Verified: '0024_c.jpg' contains '_c'.
#
# Checking zip file: /content/final_species_zips/final_Harmonia_axyridis.zip
#   Verified: '0108_h.jpg' contains '_h'.
#   Verified: '0074_h.jpg' contains '_h'.
#   Verified: '0001_h.jpg' contains '_h'.
#   Verified: '0100_h.jpg' contains '_h'.
#   Verified: '0045_h.jpg' contains '_h'.
#
# Final zip file verification complete.
